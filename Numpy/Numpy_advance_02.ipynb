# %%
import numpy as np

# %%
avinash = np.random.randint(1,10,(3,3))

# %%
avinash
# Out:
# array([[3, 7, 6],
#        [4, 6, 5],
#        [1, 5, 4]], dtype=int32)

# %%
avinash.flatten()
# Out:
# array([3, 7, 6, 4, 6, 5, 1, 5, 4], dtype=int32)

# %%
ad = np.expand_dims(avinash, axis=0)

# %%
karti = np.array([1,2,3,4])

# %%
karti
# Out:
# array([1, 2, 3, 4])

# %%
np.expand_dims(karti,axis=0)
# Out:
# array([[1, 2, 3, 4]])

# %%
np.expand_dims(karti,axis=1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
np.squeeze(avinash)
# Out:
# array([[3, 7, 6],
#        [4, 6, 5],
#        [1, 5, 4]], dtype=int32)

# %%
ad
# Out:
# array([[[3, 7, 6],
#         [4, 6, 5],
#         [1, 5, 4]]], dtype=int32)

# %%
np.squeeze(ad).ndim
# Out:
# 2

# %%
ad.ndim
# Out:
# 3

# %%
np.repeat(avinash,2)
# Out:
# array([3, 3, 7, 7, 6, 6, 4, 4, 6, 6, 5, 5, 1, 1, 5, 5, 4, 4], dtype=int32)
