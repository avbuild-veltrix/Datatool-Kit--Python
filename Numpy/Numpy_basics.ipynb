# %% [markdown]
# #Here I'm learning some basic things about Numpy.

# %% [raw]
# Data Toolkit-
# 1.Numpy
# 2.Pandas
# 3.Matplotlib
# 4.Seaborn
# 5.Plotly
# 6.Bokeh

# %% [raw]
# Data Mining: It is the process of finding relastinships, patters, treands and useful information from large satasets to support decision making

# %% [raw]
# CRISP-DM Framework: It contains the steps that needed in order to find the patters among datasets

# %% [raw]
# Numpy>> Numerical Python

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.5.1'

# %%
print(np.__doc__)
# Out:
# NumPy
# =====
#
# Provides
#   1. An array object of arbitrary homogeneous items
#   2. Fast mathematical operations over arrays
#   3. Linear Algebra, Fourier Transforms, Random Number Generation
#
# How to use the documentation
# ----------------------------
# Documentation is available in two forms: docstrings provided
# with the code, and a loose standing reference guide, available from
# `the NumPy homepage <https://numpy.org>`_.
#
# We recommend exploring the docstrings using
# `IPython <https://ipython.org>`_, an advanced Python shell with
# TAB-completion and introspection capabilities.  See below for further
# instructions.
#
# The docstring examples assume that `numpy` has been imported as ``np``::
#
#   >>> import numpy as np
#
# Code snippets are indicated by three greater-than signs::
#
#   >>> x = 42
#   >>> x = x + 1
#
# Use the built-in ``help`` function to view a function's docstring::
#
#   >>> help(np.sort)
#   ... # doctest: +SKIP
#
# ...

# %% [markdown]
# Numpy stores the data in numpy array>> homogeneous data

# %% [raw]
# Methods for converting list into array
# 1.np.array(argument)
# 2.np.asarray(argument)
# 3.np.asanyarray(argument)>>If argument is array or subclass of array it will not do anything.

# %% [raw]
# Method for converting tuple into array
# 1. np.aaray(argument)

# %%
l = [1,2,3,4,5,6,"Avi","Karti"]

# %%
arr = np.array(l)

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr
# Out:
# array(['1', '2', '3', '4', '5', '6', 'Avi', 'Karti'], dtype='<U21')

# %%
arr.ndim
# Out:
# 1

# %%
arr1 = ([[1,2,3,4,5,6],[1,2,3,"Karti","Indar","Avinash"]])

# %%
A = np.array(arr1)

# %%
arr2 = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# %%
 AV = np.array(arr2)

# %%
AV.ndim
# Out:
# 2

# %%
Karti = np.array(arr1)

# %%
matrix = np.matrix(arr2)

# %%
matrix.ndim
# Out:
# 2

# %%
A.ndim
# Out:
# 2

# %% [raw]
# Other way to create an array
# 1. np.fromfunction()# Construct an array by executing a function over each coordinate.
# 2. np.fromiter() #Create a new 1-dimensional array from an iterable object.
# 3. np.fromstring() #A new 1-D array initialized from text data in a string.
# 4. np.arange(start, stop, step)#By default step is 1

# %%
KART = np.fromfunction(lambda i,j : i==j, (3,3))

# %%
KART
# Out:
# array([[ True, False, False],
#        [False,  True, False],
#        [False, False,  True]])

# %%
KART.ndim
# Out:
# 2

# %%
KART.shape
# Out:
# (3, 3)

# %%
KART.size
# Out:
# 9

# %%
Q = np.fromfunction(lambda i,j: i*j, (5,3))

# %%
Q
# Out:
# array([[0., 0., 0.],
#        [0., 1., 2.],
#        [0., 2., 4.],
#        [0., 3., 6.],
#        [0., 4., 8.]])

# %%
Q.ndim
# Out:
# 2

# %%
Q.shape
# Out:
# (5, 3)

# %%
Q.size
# Out:
# 15

# %%
#A new 1-D array initialized from text data in a string.
#Creating array from string
S = np.fromstring(' 22 33 44', sep = " ")

# %%
S
# Out:
# array([22., 33., 44.])

# %%
#Creating array from generator
iterator = (i for i in range(5))
np.fromiter(iterator, int)
# Out:
# array([0, 1, 2, 3, 4])

# %%
string = '12 34 56'
np.fromstring(string, sep = " ")
# Out:
# array([12., 34., 56.])

# %%
np.arange(1, 10, 0.5)
# Out:
# array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ,
#        7.5, 8. , 8.5, 9. , 9.5])

# %%
np.linspace() Return evenly spaced numbers over a specified interval.
